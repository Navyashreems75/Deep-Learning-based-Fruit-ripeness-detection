# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.53.54 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.27.26 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.58.13 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.47.41 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.56.30 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.11.17 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.19.08 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.07.35 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.58.18 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.12.45 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.57.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.58.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.16.20 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.18.07 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.23 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.02.03 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.23.24 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.58.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.27.11 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.25.09 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.58.13 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.14.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.05.08 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.56.16 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.02.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.04.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.06.13 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.59.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.14.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.01.26 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.09.09 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.04.47 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.48.40 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.50.40 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.12.49 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.04.19 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.27.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.25.23 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.04.41 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.55.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.25.41 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.59.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.00.49 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.56.06 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.20.14 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.19.49 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.09.29 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.25.12 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.48.40 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.25.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.48.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.13.34 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.22.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.58.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.03.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.54.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.12.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.10.04 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.53.42 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.06.21 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.14.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.53.09 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.19.35 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.01.56 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.19.08 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.47.51 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.17.19 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.00.31 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.03.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.02.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.02.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.17.19 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.52.21 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.10.10 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.51.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.03.25 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.11.35 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.04.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.56.30 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.10.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.08.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.26.21 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.57.14 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.00.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.10.45 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.51.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.19.17 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.11.05 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.16.20 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.00.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.11.47 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.12.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.10.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.18.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.55.08 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.03.40 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.54.48 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.17.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.22.13 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.55.53 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.26.27 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.52.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.09.16 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.00.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.14.28 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.54.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.13.54 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.06.33 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.25.18 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.56.11 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.50.26 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.09.05 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.26.27 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.58.07 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.14.48 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.56.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.11 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.09.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.57.54 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.14.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.00.11 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.12.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.05.21 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.17.27 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.07.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.35 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.08.26 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.16.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.16.34 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.08.59 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.53.09 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.19.03 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.26.13 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.00.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.54 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.09.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.13.48 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.05.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.49.20 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.58.38 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.04.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.14.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.00.49 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.27.31 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.03.25 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.11.23 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.52.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.05.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.57.34 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.55.08 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.01.10 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.04.19 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.22.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.10.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.13.39 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.10.27 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.01.10 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.18.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.11.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.13.21 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.01.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.11.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.56.11 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.52 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.59.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.25.04 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.57.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.02.38 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.05.02 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.22.19 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.06.13 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.17.19 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.57.22 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.01.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.05.02 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.13.10 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.03.34 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.53.29 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.49.41 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.59.51 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.51.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.13.39 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.07 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.11.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.13.16 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.16.28 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.51.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.49.30 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.16.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.00.17 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.21.25 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.26.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.59.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.07.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.27.15 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.12.27 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.07.39 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.56.30 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.27.56 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.20.36 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.52.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.27.41 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.09.09 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.02.44 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.20.47 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.51.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.27.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.20.14 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.01.56 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.50.20 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.12.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.14.48 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.01.21 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.03.40 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.58.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.26.27 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.25.54 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.28.04 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.58.07 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 9.12.57 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.22.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 8.54.14 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.54.00 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.10.45 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.51.38 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.07.04 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 9.12.45 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.51.38 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.25.41 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 9.02.52 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.09.29 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_45_Screen Shot 2018-06-12 at 9.03.01 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.52.48 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 9.01.10 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.16.28 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_30_Screen Shot 2018-06-12 at 8.54.37 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/Screen Shot 2018-06-12 at 8.51.46 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.13.48 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.22.32 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/saltandpepper_Screen Shot 2018-06-12 at 8.49.20 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.28.09 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_60_Screen Shot 2018-06-12 at 8.47.28 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 8.59.51 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.09.43 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 8.49.59 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 8.53.42 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/translation_Screen Shot 2018-06-12 at 9.06.40 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 9.18.11 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_75_Screen Shot 2018-06-12 at 8.53.54 PM.png
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/rottenbanana/rotated_by_15_Screen Shot 2018-06-12 at 9.03.46 PM.png
# ...
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7796.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6671.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7535.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9314.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8376.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7732.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8638.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4824.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3737.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7191.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5297.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8351.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9893.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8662.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7168.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8276.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5502.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1838.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3392.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2155.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3456.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1293.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7731.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9382.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2767.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3252.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6401.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1564.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6489.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8687.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2327.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8369.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8871.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3809.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1663.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2271.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8975.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8419.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8258.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3463.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5187.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7648.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1771.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4303.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5661.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5242.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1914.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5138.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9640.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4794.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9914.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3375.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6230.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6624.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6882.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3932.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4627.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5503.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4413.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8417.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9438.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7774.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2923.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6835.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8766.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3657.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4127.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2610.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6646.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2524.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5348.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2906 - Copy.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_196.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_859.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_497.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3841.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1416.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6052.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3743.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_3858.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6691.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9398.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2570.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7114.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_740.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2627.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5301.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5366.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_883.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5734.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1558.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_280.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5082.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_5121.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6780.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_579.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8201.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8442.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2433.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_321.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_8998.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_7884.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2198.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_1932.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_2474.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6378.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_4094.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_6346.jpg
# /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/train/unripe orange/aug_0_9725.jpg

# %%
import os
import cv2

base_path = "/kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten"
dataset = os.listdir(base_path)[0]
dataset_path = os.path.join(base_path, dataset)

found = False

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.endswith('.jpg'):
            img_path = os.path.join(root, file)
            img = cv2.imread(img_path)
            print("Image path:", img_path)
            print("Image shape:", img.shape)
            found = True
            break
    if found:
        break
# Out:
# Image path: /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset/dataset/test/unripe apple/208.jpg
# Image shape: (106, 162, 3)

# %%
import os
for root, dirs, files in os.walk('/kaggle/input'):
    if 'train' in dirs and 'test' in dirs:
        print('Found:', root)
        break
# Out:
# Found: /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset

# %%
# ============================================================
# 🍎 FruitSense: Fruit Ripeness Classification
# Dataset structure:
# /kaggle/input/.../archive/dataset/train/  &  .../test/
# Classes: reshapples, freshbanana, freshoranges,
#          rottenapples, rottenbanana, rottenoranges,
#          unripe apple, unripe banana, unripe orange
# ============================================================

# ── STEP 1: Import Libraries ──────────────────────────────────
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import warnings
import cv2
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121, VGG16, ResNet50, MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import (
    classification_report, confusion_matrix,
    accuracy_score, precision_score, recall_score, f1_score
)
from sklearn.model_selection import train_test_split
import shutil

print('✅ TensorFlow:', tf.__version__)
print('✅ GPU:', tf.config.list_physical_devices('GPU'))


# ── STEP 2: Find Correct Path Automatically ───────────────────
# This auto-detects the exact path so you don't have to guess
def find_dataset_path(base='/kaggle/input'):
    """Walk input folder and find where train/ and test/ live."""
    for root, dirs, files in os.walk(base):
        if 'train' in dirs and 'test' in dirs:
            print(f'✅ Found dataset at: {root}')
            return root
    raise FileNotFoundError('❌ Could not find train/ and test/ folders!')

BASE_DIR  = find_dataset_path()
TRAIN_DIR = os.path.join(BASE_DIR, 'train')
TEST_DIR  = os.path.join(BASE_DIR, 'test')
VAL_DIR   = '/kaggle/working/val'

IMG_SIZE    = (224, 224)
BATCH_SIZE  = 32
EPOCHS      = 30
LR          = 0.0001
NUM_CLASSES = 9
SEED        = 42

# ── Verify all 9 classes ──────────────────────────────────────
print('\n📂 Train classes:')
for cls in sorted(os.listdir(TRAIN_DIR)):
    n = len([f for f in os.listdir(os.path.join(TRAIN_DIR, cls))
             if f.lower().endswith(('.jpg','.jpeg','.png'))])
    print(f'  {cls:20s} → {n} images')

print('\n📂 Test classes:')
for cls in sorted(os.listdir(TEST_DIR)):
    n = len([f for f in os.listdir(os.path.join(TEST_DIR, cls))
             if f.lower().endswith(('.jpg','.jpeg','.png'))])
    print(f'  {cls:20s} → {n} images')


# ── STEP 3: Carve 15% of Train → Validation ──────────────────
print('\n⏳ Creating validation set (15% of train)...')
os.makedirs(VAL_DIR, exist_ok=True)

for cls in sorted(os.listdir(TRAIN_DIR)):
    src_cls_dir = os.path.join(TRAIN_DIR, cls)
    val_cls_dir = os.path.join(VAL_DIR,   cls)
    os.makedirs(val_cls_dir, exist_ok=True)

    all_imgs = [f for f in os.listdir(src_cls_dir)
                if f.lower().endswith(('.jpg','.jpeg','.png'))]

    _, val_imgs = train_test_split(all_imgs, test_size=0.15, random_state=SEED)

    for img in val_imgs:
        src  = os.path.join(src_cls_dir, img)
        dest = os.path.join(val_cls_dir, img)
        if not os.path.exists(dest):
            shutil.copy2(src, dest)

    print(f'  {cls:20s} → {len(val_imgs)} val images')

print('✅ Validation set ready!')


# ── STEP 4: Data Augmentation & Generators ───────────────────
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True, seed=SEED
)
val_gen = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
test_gen = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

class_names = list(train_gen.class_indices.keys())
print(f'\n✅ Train : {train_gen.samples} images')
print(f'✅ Val   : {val_gen.samples} images')
print(f'✅ Test  : {test_gen.samples} images')
print(f'\n📋 Classes ({len(class_names)}): {class_names}')


# ── STEP 5: Visualize Sample Images ──────────────────────────
def plot_samples(generator, class_indices):
    idx_to_class = {v: k for k, v in class_indices.items()}
    images, labels = next(generator)
    fig, axes = plt.subplots(3, 3, figsize=(12, 10))
    fig.suptitle('📸 Sample Images per Class', fontsize=15, fontweight='bold')
    for i, ax in enumerate(axes.flat):
        if i < len(images):
            ax.imshow(images[i])
            ax.set_title(idx_to_class[np.argmax(labels[i])], fontsize=9)
        ax.axis('off')
    plt.tight_layout()
    plt.savefig('/kaggle/working/sample_images.png', dpi=150)
    plt.show()

plot_samples(train_gen, train_gen.class_indices)


# ── STEP 6: Build Transfer Learning Models ───────────────────
def build_model(base_fn, name, num_classes=9, lr=0.0001):
    base = base_fn(weights='imagenet', include_top=False,
                   input_shape=(*IMG_SIZE, 3))
    base.trainable = False

    inputs  = keras.Input(shape=(*IMG_SIZE, 3))
    x       = base(inputs, training=False)
    x       = layers.GlobalAveragePooling2D()(x)
    x       = layers.BatchNormalization()(x)
    x       = layers.Dense(512, activation='relu')(x)
    x       = layers.Dropout(0.4)(x)
    x       = layers.Dense(256, activation='relu')(x)
    x       = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs, name=name)
    model.compile(optimizer=Adam(lr),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    print(f'✅ {name} — params: {model.count_params():,}')
    return model

models_dict = {
    'DenseNet121' : build_model(DenseNet121,  'DenseNet121'),
    'VGG16'       : build_model(VGG16,        'VGG16'),
    'ResNet50'    : build_model(ResNet50,      'ResNet50'),
    'MobileNetV2' : build_model(MobileNetV2,  'MobileNetV2'),
}


# ── STEP 7: Callbacks ─────────────────────────────────────────
def get_callbacks(name):
    return [
        EarlyStopping(monitor='val_accuracy', patience=5,
                      restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                          patience=3, min_lr=1e-7, verbose=1),
        ModelCheckpoint(f'/kaggle/working/{name}_best.keras',
                        monitor='val_accuracy', save_best_only=True)
    ]


# ── STEP 8: Train All Models ──────────────────────────────────
histories = {}
for name, model in models_dict.items():
    print(f'\n{"="*55}')
    print(f'🏋️  Training {name}...')
    print(f'{"="*55}')
    history = model.fit(
        train_gen, epochs=EPOCHS,
        validation_data=val_gen,
        callbacks=get_callbacks(name),
        verbose=1
    )
    histories[name] = history
    print(f'✅ {name} done!')


# ── STEP 9: Fine-Tune DenseNet121 ────────────────────────────
print('\n🔓 Fine-tuning DenseNet121 (unfreeze last 50 layers)...')
densenet   = models_dict['DenseNet121']
base_layer = densenet.layers[1]
for layer in base_layer.layers[-50:]:
    layer.trainable = True

densenet.compile(optimizer=Adam(1e-5),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

ft_history = densenet.fit(
    train_gen, epochs=15,
    validation_data=val_gen,
    callbacks=get_callbacks('DenseNet121_ft'),
    verbose=1
)
histories['DenseNet121_FT'] = ft_history
print('✅ Fine-tuning complete!')


# ── STEP 10: Plot Training Curves ────────────────────────────
def plot_history(history, name):
    fig, ax = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f'📈 {name} Training History', fontsize=13, fontweight='bold')
    ax[0].plot(history.history['accuracy'],     label='Train', color='#2D6A4F', lw=2)
    ax[0].plot(history.history['val_accuracy'], label='Val',   color='#F4A261', lw=2)
    ax[0].set_title('Accuracy'); ax[0].legend(); ax[0].grid(alpha=0.3)
    ax[1].plot(history.history['loss'],         label='Train', color='#2D6A4F', lw=2)
    ax[1].plot(history.history['val_loss'],     label='Val',   color='#E76F51', lw=2)
    ax[1].set_title('Loss'); ax[1].legend(); ax[1].grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(f'/kaggle/working/{name}_history.png', dpi=150)
    plt.show()

for name, hist in histories.items():
    plot_history(hist, name)


# ── STEP 11: Evaluate All Models ─────────────────────────────
def evaluate_model(model, generator, name):
    generator.reset()
    y_pred    = np.argmax(model.predict(generator, verbose=0), axis=1)
    y_true    = generator.classes
    acc       = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall    = recall_score(y_true, y_pred, average='weighted')
    f1        = f1_score(y_true, y_pred, average='weighted')
    recalls   = recall_score(y_true, y_pred, average=None)
    gmean     = np.prod(recalls) ** (1.0 / len(recalls))

    print(f'\n📊 {name}:')
    print(f'  Accuracy   : {acc*100:.2f}%')
    print(f'  Precision  : {precision*100:.2f}%')
    print(f'  Recall     : {recall*100:.2f}%')
    print(f'  F1-Score   : {f1*100:.2f}%')
    print(f'  G-Mean     : {gmean*100:.2f}%')
    print(f'  Error Rate : {(1-acc)*100:.2f}%')

    return {
        'Model'      : name,
        'Accuracy'   : round(acc*100, 2),
        'Precision'  : round(precision*100, 2),
        'Recall'     : round(recall*100, 2),
        'F1-Score'   : round(f1*100, 2),
        'G-Mean'     : round(gmean*100, 2),
        'Error Rate' : round((1-acc)*100, 2),
        'y_true'     : y_true,
        'y_pred'     : y_pred
    }

results = {name: evaluate_model(m, test_gen, name)
           for name, m in models_dict.items()}


# ── STEP 12: Comparison Table & Chart ────────────────────────
cols = ['Model','Accuracy','Precision','Recall','F1-Score','G-Mean','Error Rate']
df   = pd.DataFrame([{k: v for k,v in r.items() if k in cols}
                     for r in results.values()])
df   = df.sort_values('Accuracy', ascending=False)

print('\n🏆 MODEL COMPARISON:')
print(df.to_string(index=False))
df.to_csv('/kaggle/working/model_comparison.csv', index=False)

fig, ax = plt.subplots(figsize=(12, 5))
x = np.arange(len(df)); w = 0.2
colors = ['#2D6A4F','#52B788','#F4A261','#E76F51']
for i, (m, c) in enumerate(zip(['Accuracy','Precision','Recall','F1-Score'], colors)):
    ax.bar(x + i*w, df[m], w, label=m, color=c)
ax.set_xticks(x + w*1.5)
ax.set_xticklabels(df['Model'], fontsize=11)
ax.set_ylabel('Score (%)'); ax.legend()
ax.set_title('📊 Model Comparison', fontsize=13, fontweight='bold')
ax.set_ylim(85, 101); ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('/kaggle/working/model_comparison.png', dpi=150)
plt.show()


# ── STEP 13: Confusion Matrix ─────────────────────────────────
def plot_cm(y_true, y_pred, labels, name):
    cm_val = confusion_matrix(y_true, y_pred)
    cm_pct = cm_val.astype('float') / cm_val.sum(axis=1)[:, None] * 100
    fig, ax = plt.subplots(figsize=(12, 10))
    sns.heatmap(cm_pct, annot=True, fmt='.1f', cmap='YlGn',
                xticklabels=labels, yticklabels=labels, ax=ax)
    ax.set_title(f'🔥 Confusion Matrix — {name} (%)', fontsize=13, fontweight='bold')
    ax.set_ylabel('True Label'); ax.set_xlabel('Predicted Label')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(f'/kaggle/working/{name}_cm.png', dpi=150)
    plt.show()

plot_cm(results['DenseNet121']['y_true'],
        results['DenseNet121']['y_pred'],
        class_names, 'DenseNet121')

print('\n📋 Classification Report — DenseNet121:')
print(classification_report(
    results['DenseNet121']['y_true'],
    results['DenseNet121']['y_pred'],
    target_names=class_names))


# ── STEP 14: Grad-CAM ─────────────────────────────────────────
def make_gradcam(img_array, model, last_conv_name):
    grad_model = keras.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(last_conv_name).output, model.output])
    with tf.GradientTape() as tape:
        conv_out, preds = grad_model(img_array)
        idx  = tf.argmax(preds[0])
        loss = preds[:, idx]
    grads   = tape.gradient(loss, conv_out)
    pooled  = tf.reduce_mean(grads, axis=(0,1,2))
    heatmap = conv_out[0] @ pooled[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy(), int(idx)

def show_gradcam(img_path, model, last_conv, class_names):
    img     = keras.utils.load_img(img_path, target_size=IMG_SIZE)
    arr     = keras.utils.img_to_array(img) / 255.0
    heatmap, pred_idx = make_gradcam(np.expand_dims(arr, 0), model, last_conv)
    heatmap_r = cv2.resize(heatmap, IMG_SIZE)
    overlay   = cm.jet(heatmap_r)[:,:,:3] * 0.5 + arr * 0.5
    overlay   = np.clip(overlay, 0, 1)
    fig, axes = plt.subplots(1, 3, figsize=(14, 4))
    axes[0].imshow(arr);               axes[0].set_title('Original');  axes[0].axis('off')
    axes[1].imshow(heatmap_r,cmap='jet'); axes[1].set_title('Heatmap'); axes[1].axis('off')
    axes[2].imshow(overlay);           axes[2].set_title(f'Predicted:\n{class_names[pred_idx]}'); axes[2].axis('off')
    plt.suptitle('👁️ Grad-CAM — DenseNet121', fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.savefig('/kaggle/working/gradcam.png', dpi=150)
    plt.show()

base_layer = models_dict['DenseNet121'].layers[1]
last_conv  = [l.name for l in base_layer.layers if 'conv' in l.name.lower()][-1]
sample_cls = sorted(os.listdir(TEST_DIR))[0]
sample_img = os.path.join(TEST_DIR, sample_cls,
                          os.listdir(os.path.join(TEST_DIR, sample_cls))[0])
show_gradcam(sample_img, models_dict['DenseNet121'], last_conv, class_names)


# ── STEP 15: Single Image Prediction ─────────────────────────
def predict_image(img_path, model, class_names):
    img   = keras.utils.load_img(img_path, target_size=IMG_SIZE)
    arr   = keras.utils.img_to_array(img) / 255.0
    preds = model.predict(np.expand_dims(arr, 0), verbose=0)[0]
    top3  = np.argsort(preds)[::-1][:3]
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(img); axes[0].set_title('Input Image'); axes[0].axis('off')
    colors = ['#2D6A4F' if i==0 else '#94A3B8' for i in range(3)]
    axes[1].barh([class_names[i] for i in top3],
                 [preds[i]*100 for i in top3], color=colors)
    axes[1].set_xlabel('Confidence (%)')
    axes[1].set_title(f'Prediction: {class_names[top3[0]]}\n({preds[top3[0]]*100:.1f}%)')
    axes[1].grid(axis='x', alpha=0.3)
    plt.tight_layout(); plt.show()
    return class_names[top3[0]], preds[top3[0]]*100

pred_class, conf = predict_image(sample_img, models_dict['DenseNet121'], class_names)
print(f'\n✅ Predicted: {pred_class} ({conf:.2f}% confidence)')


# ── STEP 16: Save Model ───────────────────────────────────────
models_dict['DenseNet121'].save('/kaggle/working/FruitSense_DenseNet121.keras')
converter = tf.lite.TFLiteConverter.from_keras_model(models_dict['DenseNet121'])
tflite    = converter.convert()
with open('/kaggle/working/FruitSense_DenseNet121.tflite', 'wb') as f:
    f.write(tflite)
print('✅ Both models saved!')


# ── STEP 17: Final Summary ────────────────────────────────────
print('\n' + '='*60)
print('       🍎 FRUITSENSE — FINAL SUMMARY')
print('='*60)
print(f'  Classes     : {class_names}')
print(f'  Train images: {train_gen.samples}')
print(f'  Val images  : {val_gen.samples}')
print(f'  Test images : {test_gen.samples}')
print('='*60)
print(df[cols].to_string(index=False))
print('='*60)
best = df.iloc[0]
print(f'\n🥇 Best: {best["Model"]} | Acc: {best["Accuracy"]}% | F1: {best["F1-Score"]}%')
print('='*60)
# Out:
# 2026-04-14 16:31:53.473919: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776184313.685142      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776184313.738708      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776184314.151237      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776184314.151284      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776184314.151287      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776184314.151290      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ✅ TensorFlow: 2.19.0
# ✅ GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ Found dataset at: /kaggle/input/datasets/leftin/fruit-ripeness-unripe-ripe-and-rotten/fruit_ripeness_dataset/archive (1)/dataset
#
# 📂 Train classes:
#   freshapples          → 1693 images
#   freshbanana          → 1581 images
#   freshoranges         → 1466 images
#   rottenapples         → 2342 images
#   rottenbanana         → 2224 images
#   rottenoranges        → 1595 images
#   unripe apple         → 1934 images
#   unripe banana        → 2097 images
#   unripe orange        → 1285 images
#
# 📂 Test classes:
#   freshapples          → 395 images
#   freshbanana          → 381 images
#   freshoranges         → 388 images
#   rottenapples         → 601 images
#   rottenbanana         → 530 images
#   rottenoranges        → 403 images
#   unripe apple         → 371 images
#   unripe banana        → 400 images
#   unripe orange        → 270 images
#
# ⏳ Creating validation set (15% of train)...
#   freshapples          → 254 val images
#   freshbanana          → 238 val images
#   freshoranges         → 220 val images
#   rottenapples         → 352 val images
#   rottenbanana         → 334 val images
#   rottenoranges        → 240 val images
#   unripe apple         → 291 val images
#   unripe banana        → 315 val images
#   unripe orange        → 193 val images
# ✅ Validation set ready!
# Found 16217 images belonging to 9 classes.
# Found 2437 images belonging to 9 classes.
# Found 3739 images belonging to 9 classes.
#
# ✅ Train : 16217 images
# ✅ Val   : 2437 images
# ✅ Test  : 3739 images
#
# 📋 Classes (9): ['freshapples', 'freshbanana', 'freshoranges', 'rottenapples', 'rottenbanana', 'rottenoranges', 'unripe apple', 'unripe banana', 'unripe orange']
# I0000 00:00:1776184354.558138      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ✅ DenseNet121 — params: 7,700,041
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ✅ VGG16 — params: 15,113,033
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ✅ ResNet50 — params: 24,778,633
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ✅ MobileNetV2 — params: 3,052,617
#
# =======================================================
# 🏋️  Training DenseNet121...
# =======================================================
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776184376.091123      90 service.cc:152] XLA service 0x7e31e40039e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776184376.091164      90 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1776184379.571724      90 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   2/507 ━━━━━━━━━━━━━━━━━━━━ 37s 74ms/step - accuracy: 0.0703 - loss: 2.7424
# I0000 00:00:1776184392.088766      90 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 361s 656ms/step - accuracy: 0.5583 - loss: 1.2601 - val_accuracy: 0.9188 - val_loss: 0.2153 - learning_rate: 1.0000e-04
# Epoch 2/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 456ms/step - accuracy: 0.8633 - loss: 0.3628 - val_accuracy: 0.9438 - val_loss: 0.1492 - learning_rate: 1.0000e-04
# Epoch 3/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 464ms/step - accuracy: 0.9029 - loss: 0.2619 - val_accuracy: 0.9594 - val_loss: 0.1062 - learning_rate: 1.0000e-04
# Epoch 4/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 461ms/step - accuracy: 0.9115 - loss: 0.2269 - val_accuracy: 0.9668 - val_loss: 0.0900 - learning_rate: 1.0000e-04
# Epoch 5/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 241s 475ms/step - accuracy: 0.9272 - loss: 0.1918 - val_accuracy: 0.9741 - val_loss: 0.0721 - learning_rate: 1.0000e-04
# Epoch 6/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.9358 - loss: 0.1718 - val_accuracy: 0.9811 - val_loss: 0.0570 - learning_rate: 1.0000e-04
# Epoch 7/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 461ms/step - accuracy: 0.9325 - loss: 0.1691 - val_accuracy: 0.9799 - val_loss: 0.0578 - learning_rate: 1.0000e-04
# Epoch 8/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 460ms/step - accuracy: 0.9432 - loss: 0.1487 - val_accuracy: 0.9848 - val_loss: 0.0478 - learning_rate: 1.0000e-04
# Epoch 9/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 232s 458ms/step - accuracy: 0.9489 - loss: 0.1345 - val_accuracy: 0.9860 - val_loss: 0.0429 - learning_rate: 1.0000e-04
# Epoch 10/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9511 - loss: 0.1325 - val_accuracy: 0.9840 - val_loss: 0.0427 - learning_rate: 1.0000e-04
# Epoch 11/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9519 - loss: 0.1222 - val_accuracy: 0.9885 - val_loss: 0.0368 - learning_rate: 1.0000e-04
# Epoch 12/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 240s 473ms/step - accuracy: 0.9614 - loss: 0.1030 - val_accuracy: 0.9889 - val_loss: 0.0312 - learning_rate: 1.0000e-04
# Epoch 13/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9608 - loss: 0.1020 - val_accuracy: 0.9914 - val_loss: 0.0285 - learning_rate: 1.0000e-04
# Epoch 14/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 463ms/step - accuracy: 0.9615 - loss: 0.1018 - val_accuracy: 0.9902 - val_loss: 0.0294 - learning_rate: 1.0000e-04
# Epoch 15/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9632 - loss: 0.0950 - val_accuracy: 0.9910 - val_loss: 0.0267 - learning_rate: 1.0000e-04
# Epoch 16/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9658 - loss: 0.0885 - val_accuracy: 0.9943 - val_loss: 0.0228 - learning_rate: 1.0000e-04
# Epoch 17/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 468ms/step - accuracy: 0.9683 - loss: 0.0867 - val_accuracy: 0.9926 - val_loss: 0.0237 - learning_rate: 1.0000e-04
# Epoch 18/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9702 - loss: 0.0823 - val_accuracy: 0.9938 - val_loss: 0.0207 - learning_rate: 1.0000e-04
# Epoch 19/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 471ms/step - accuracy: 0.9670 - loss: 0.0824 - val_accuracy: 0.9930 - val_loss: 0.0186 - learning_rate: 1.0000e-04
# Epoch 20/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 469ms/step - accuracy: 0.9702 - loss: 0.0799 - val_accuracy: 0.9959 - val_loss: 0.0165 - learning_rate: 1.0000e-04
# Epoch 21/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 468ms/step - accuracy: 0.9723 - loss: 0.0689 - val_accuracy: 0.9955 - val_loss: 0.0133 - learning_rate: 1.0000e-04
# Epoch 22/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 240s 473ms/step - accuracy: 0.9737 - loss: 0.0721 - val_accuracy: 0.9947 - val_loss: 0.0158 - learning_rate: 1.0000e-04
# Epoch 23/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9749 - loss: 0.0666 - val_accuracy: 0.9955 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 24/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9761 - loss: 0.0666 - val_accuracy: 0.9963 - val_loss: 0.0116 - learning_rate: 1.0000e-04
# Epoch 25/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 471ms/step - accuracy: 0.9759 - loss: 0.0656 - val_accuracy: 0.9967 - val_loss: 0.0111 - learning_rate: 1.0000e-04
# Epoch 26/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 464ms/step - accuracy: 0.9764 - loss: 0.0632 - val_accuracy: 0.9963 - val_loss: 0.0123 - learning_rate: 1.0000e-04
# Epoch 27/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.9807 - loss: 0.0537 - val_accuracy: 0.9963 - val_loss: 0.0131 - learning_rate: 1.0000e-04
# Epoch 28/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9764 - loss: 0.0579 - val_accuracy: 0.9971 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 29/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 456ms/step - accuracy: 0.9780 - loss: 0.0600 - val_accuracy: 0.9971 - val_loss: 0.0095 - learning_rate: 1.0000e-04
# Epoch 30/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9796 - loss: 0.0558 - val_accuracy: 0.9971 - val_loss: 0.0077 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 28.
# ✅ DenseNet121 done!
#
# =======================================================
# 🏋️  Training VGG16...
# =======================================================
# Epoch 1/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 256s 485ms/step - accuracy: 0.4340 - loss: 1.5570 - val_accuracy: 0.8252 - val_loss: 0.5494 - learning_rate: 1.0000e-04
# Epoch 2/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.7157 - loss: 0.7449 - val_accuracy: 0.8695 - val_loss: 0.3402 - learning_rate: 1.0000e-04
# Epoch 3/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 244s 482ms/step - accuracy: 0.7735 - loss: 0.5892 - val_accuracy: 0.8884 - val_loss: 0.2913 - learning_rate: 1.0000e-04
# Epoch 4/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 246s 486ms/step - accuracy: 0.8015 - loss: 0.5234 - val_accuracy: 0.9007 - val_loss: 0.2577 - learning_rate: 1.0000e-04
# Epoch 5/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 249s 491ms/step - accuracy: 0.8174 - loss: 0.4650 - val_accuracy: 0.9089 - val_loss: 0.2298 - learning_rate: 1.0000e-04
# Epoch 6/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 472ms/step - accuracy: 0.8289 - loss: 0.4370 - val_accuracy: 0.9159 - val_loss: 0.2073 - learning_rate: 1.0000e-04
# Epoch 7/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 471ms/step - accuracy: 0.8481 - loss: 0.3948 - val_accuracy: 0.9229 - val_loss: 0.1954 - learning_rate: 1.0000e-04
# Epoch 8/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 462ms/step - accuracy: 0.8529 - loss: 0.3695 - val_accuracy: 0.9307 - val_loss: 0.1825 - learning_rate: 1.0000e-04
# Epoch 9/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.8631 - loss: 0.3510 - val_accuracy: 0.9339 - val_loss: 0.1708 - learning_rate: 1.0000e-04
# Epoch 10/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 463ms/step - accuracy: 0.8673 - loss: 0.3439 - val_accuracy: 0.9405 - val_loss: 0.1538 - learning_rate: 1.0000e-04
# Epoch 11/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.8734 - loss: 0.3354 - val_accuracy: 0.9368 - val_loss: 0.1564 - learning_rate: 1.0000e-04
# Epoch 12/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 472ms/step - accuracy: 0.8743 - loss: 0.3228 - val_accuracy: 0.9438 - val_loss: 0.1403 - learning_rate: 1.0000e-04
# Epoch 13/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 244s 482ms/step - accuracy: 0.8798 - loss: 0.3150 - val_accuracy: 0.9503 - val_loss: 0.1315 - learning_rate: 1.0000e-04
# Epoch 14/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 243s 479ms/step - accuracy: 0.8890 - loss: 0.2918 - val_accuracy: 0.9602 - val_loss: 0.1199 - learning_rate: 1.0000e-04
# Epoch 15/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 240s 473ms/step - accuracy: 0.8888 - loss: 0.2938 - val_accuracy: 0.9561 - val_loss: 0.1171 - learning_rate: 1.0000e-04
# Epoch 16/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 470ms/step - accuracy: 0.8940 - loss: 0.2804 - val_accuracy: 0.9586 - val_loss: 0.1135 - learning_rate: 1.0000e-04
# Epoch 17/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 471ms/step - accuracy: 0.8973 - loss: 0.2790 - val_accuracy: 0.9606 - val_loss: 0.1098 - learning_rate: 1.0000e-04
# Epoch 18/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 470ms/step - accuracy: 0.8977 - loss: 0.2652 - val_accuracy: 0.9618 - val_loss: 0.1075 - learning_rate: 1.0000e-04
# Epoch 19/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 241s 475ms/step - accuracy: 0.9013 - loss: 0.2588 - val_accuracy: 0.9659 - val_loss: 0.0965 - learning_rate: 1.0000e-04
# Epoch 20/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 240s 473ms/step - accuracy: 0.9025 - loss: 0.2591 - val_accuracy: 0.9655 - val_loss: 0.0931 - learning_rate: 1.0000e-04
# Epoch 21/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 468ms/step - accuracy: 0.9052 - loss: 0.2502 - val_accuracy: 0.9659 - val_loss: 0.0961 - learning_rate: 1.0000e-04
# Epoch 22/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9133 - loss: 0.2356 - val_accuracy: 0.9659 - val_loss: 0.0899 - learning_rate: 1.0000e-04
# Epoch 23/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9150 - loss: 0.2247 - val_accuracy: 0.9692 - val_loss: 0.0861 - learning_rate: 1.0000e-04
# Epoch 24/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 469ms/step - accuracy: 0.9108 - loss: 0.2378 - val_accuracy: 0.9737 - val_loss: 0.0824 - learning_rate: 1.0000e-04
# Epoch 25/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 466ms/step - accuracy: 0.9099 - loss: 0.2243 - val_accuracy: 0.9680 - val_loss: 0.0894 - learning_rate: 1.0000e-04
# Epoch 26/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9131 - loss: 0.2306 - val_accuracy: 0.9700 - val_loss: 0.0813 - learning_rate: 1.0000e-04
# Epoch 27/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 469ms/step - accuracy: 0.9184 - loss: 0.2106 - val_accuracy: 0.9750 - val_loss: 0.0743 - learning_rate: 1.0000e-04
# Epoch 28/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9160 - loss: 0.2193 - val_accuracy: 0.9783 - val_loss: 0.0681 - learning_rate: 1.0000e-04
# Epoch 29/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 239s 471ms/step - accuracy: 0.9205 - loss: 0.2089 - val_accuracy: 0.9762 - val_loss: 0.0685 - learning_rate: 1.0000e-04
# Epoch 30/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 240s 472ms/step - accuracy: 0.9216 - loss: 0.2079 - val_accuracy: 0.9783 - val_loss: 0.0686 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 28.
# ✅ VGG16 done!
#
# =======================================================
# 🏋️  Training ResNet50...
# =======================================================
# Epoch 1/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 260s 489ms/step - accuracy: 0.2570 - loss: 1.9341 - val_accuracy: 0.4563 - val_loss: 1.4572 - learning_rate: 1.0000e-04
# Epoch 2/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.3759 - loss: 1.5772 - val_accuracy: 0.5002 - val_loss: 1.2295 - learning_rate: 1.0000e-04
# Epoch 3/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 466ms/step - accuracy: 0.4115 - loss: 1.4725 - val_accuracy: 0.5339 - val_loss: 1.1591 - learning_rate: 1.0000e-04
# Epoch 4/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.4415 - loss: 1.3967 - val_accuracy: 0.5540 - val_loss: 1.0954 - learning_rate: 1.0000e-04
# Epoch 5/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.4530 - loss: 1.3614 - val_accuracy: 0.5691 - val_loss: 1.0685 - learning_rate: 1.0000e-04
# Epoch 6/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 462ms/step - accuracy: 0.4643 - loss: 1.3338 - val_accuracy: 0.5868 - val_loss: 1.0301 - learning_rate: 1.0000e-04
# Epoch 7/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.4807 - loss: 1.2757 - val_accuracy: 0.6011 - val_loss: 0.9953 - learning_rate: 1.0000e-04
# Epoch 8/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 469ms/step - accuracy: 0.4975 - loss: 1.2620 - val_accuracy: 0.5868 - val_loss: 0.9980 - learning_rate: 1.0000e-04
# Epoch 9/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.5054 - loss: 1.2283 - val_accuracy: 0.5983 - val_loss: 0.9649 - learning_rate: 1.0000e-04
# Epoch 10/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 466ms/step - accuracy: 0.5027 - loss: 1.2275 - val_accuracy: 0.6139 - val_loss: 0.9682 - learning_rate: 1.0000e-04
# Epoch 11/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.5185 - loss: 1.1999 - val_accuracy: 0.6282 - val_loss: 0.9263 - learning_rate: 1.0000e-04
# Epoch 12/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 466ms/step - accuracy: 0.5156 - loss: 1.2057 - val_accuracy: 0.6286 - val_loss: 0.9168 - learning_rate: 1.0000e-04
# Epoch 13/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 468ms/step - accuracy: 0.5226 - loss: 1.1720 - val_accuracy: 0.6340 - val_loss: 0.9080 - learning_rate: 1.0000e-04
# Epoch 14/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 469ms/step - accuracy: 0.5350 - loss: 1.1578 - val_accuracy: 0.6631 - val_loss: 0.8559 - learning_rate: 1.0000e-04
# Epoch 15/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.5416 - loss: 1.1401 - val_accuracy: 0.6336 - val_loss: 0.8940 - learning_rate: 1.0000e-04
# Epoch 16/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 463ms/step - accuracy: 0.5339 - loss: 1.1430 - val_accuracy: 0.6508 - val_loss: 0.8765 - learning_rate: 1.0000e-04
# Epoch 17/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.5406 - loss: 1.1414
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.5406 - loss: 1.1413 - val_accuracy: 0.6512 - val_loss: 0.8623 - learning_rate: 1.0000e-04
# Epoch 18/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 463ms/step - accuracy: 0.5488 - loss: 1.1266 - val_accuracy: 0.6483 - val_loss: 0.8635 - learning_rate: 3.0000e-05
# Epoch 19/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 463ms/step - accuracy: 0.5479 - loss: 1.1109 - val_accuracy: 0.6639 - val_loss: 0.8462 - learning_rate: 3.0000e-05
# Epoch 20/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.5552 - loss: 1.1093 - val_accuracy: 0.6586 - val_loss: 0.8520 - learning_rate: 3.0000e-05
# Epoch 21/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 461ms/step - accuracy: 0.5573 - loss: 1.0919 - val_accuracy: 0.6561 - val_loss: 0.8539 - learning_rate: 3.0000e-05
# Epoch 22/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.5606 - loss: 1.1001
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.5606 - loss: 1.1001 - val_accuracy: 0.6602 - val_loss: 0.8465 - learning_rate: 3.0000e-05
# Epoch 23/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 461ms/step - accuracy: 0.5605 - loss: 1.0871 - val_accuracy: 0.6565 - val_loss: 0.8382 - learning_rate: 9.0000e-06
# Epoch 24/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 232s 457ms/step - accuracy: 0.5643 - loss: 1.0850 - val_accuracy: 0.6590 - val_loss: 0.8380 - learning_rate: 9.0000e-06
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# ✅ ResNet50 done!
#
# =======================================================
# 🏋️  Training MobileNetV2...
# =======================================================
# Epoch 1/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 261s 489ms/step - accuracy: 0.5544 - loss: 1.3002 - val_accuracy: 0.9036 - val_loss: 0.2471 - learning_rate: 1.0000e-04
# Epoch 2/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 456ms/step - accuracy: 0.8420 - loss: 0.4177 - val_accuracy: 0.9319 - val_loss: 0.1798 - learning_rate: 1.0000e-04
# Epoch 3/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 232s 458ms/step - accuracy: 0.8716 - loss: 0.3380 - val_accuracy: 0.9409 - val_loss: 0.1508 - learning_rate: 1.0000e-04
# Epoch 4/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 456ms/step - accuracy: 0.8954 - loss: 0.2823 - val_accuracy: 0.9508 - val_loss: 0.1288 - learning_rate: 1.0000e-04
# Epoch 5/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 468ms/step - accuracy: 0.9030 - loss: 0.2516 - val_accuracy: 0.9528 - val_loss: 0.1171 - learning_rate: 1.0000e-04
# Epoch 6/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 460ms/step - accuracy: 0.9121 - loss: 0.2312 - val_accuracy: 0.9622 - val_loss: 0.1053 - learning_rate: 1.0000e-04
# Epoch 7/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 457ms/step - accuracy: 0.9176 - loss: 0.2117 - val_accuracy: 0.9639 - val_loss: 0.0938 - learning_rate: 1.0000e-04
# Epoch 8/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 456ms/step - accuracy: 0.9234 - loss: 0.2061 - val_accuracy: 0.9700 - val_loss: 0.0846 - learning_rate: 1.0000e-04
# Epoch 9/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 232s 457ms/step - accuracy: 0.9310 - loss: 0.1817 - val_accuracy: 0.9733 - val_loss: 0.0792 - learning_rate: 1.0000e-04
# Epoch 10/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 455ms/step - accuracy: 0.9298 - loss: 0.1847 - val_accuracy: 0.9778 - val_loss: 0.0735 - learning_rate: 1.0000e-04
# Epoch 11/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.9326 - loss: 0.1736 - val_accuracy: 0.9774 - val_loss: 0.0673 - learning_rate: 1.0000e-04
# Epoch 12/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 460ms/step - accuracy: 0.9370 - loss: 0.1655 - val_accuracy: 0.9799 - val_loss: 0.0649 - learning_rate: 1.0000e-04
# Epoch 13/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.9401 - loss: 0.1567 - val_accuracy: 0.9803 - val_loss: 0.0603 - learning_rate: 1.0000e-04
# Epoch 14/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 463ms/step - accuracy: 0.9396 - loss: 0.1531 - val_accuracy: 0.9795 - val_loss: 0.0634 - learning_rate: 1.0000e-04
# Epoch 15/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9416 - loss: 0.1447 - val_accuracy: 0.9836 - val_loss: 0.0561 - learning_rate: 1.0000e-04
# Epoch 16/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 461ms/step - accuracy: 0.9503 - loss: 0.1297 - val_accuracy: 0.9840 - val_loss: 0.0516 - learning_rate: 1.0000e-04
# Epoch 17/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 460ms/step - accuracy: 0.9460 - loss: 0.1373 - val_accuracy: 0.9860 - val_loss: 0.0493 - learning_rate: 1.0000e-04
# Epoch 18/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9492 - loss: 0.1400 - val_accuracy: 0.9828 - val_loss: 0.0514 - learning_rate: 1.0000e-04
# Epoch 19/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9522 - loss: 0.1255 - val_accuracy: 0.9807 - val_loss: 0.0504 - learning_rate: 1.0000e-04
# Epoch 20/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 460ms/step - accuracy: 0.9556 - loss: 0.1182 - val_accuracy: 0.9860 - val_loss: 0.0431 - learning_rate: 1.0000e-04
# Epoch 21/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9546 - loss: 0.1193 - val_accuracy: 0.9873 - val_loss: 0.0438 - learning_rate: 1.0000e-04
# Epoch 22/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9587 - loss: 0.1119 - val_accuracy: 0.9897 - val_loss: 0.0408 - learning_rate: 1.0000e-04
# Epoch 23/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 460ms/step - accuracy: 0.9585 - loss: 0.1115 - val_accuracy: 0.9852 - val_loss: 0.0427 - learning_rate: 1.0000e-04
# Epoch 24/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9573 - loss: 0.1172 - val_accuracy: 0.9873 - val_loss: 0.0403 - learning_rate: 1.0000e-04
# Epoch 25/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 462ms/step - accuracy: 0.9607 - loss: 0.1107 - val_accuracy: 0.9926 - val_loss: 0.0356 - learning_rate: 1.0000e-04
# Epoch 26/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.9606 - loss: 0.1049 - val_accuracy: 0.9906 - val_loss: 0.0342 - learning_rate: 1.0000e-04
# Epoch 27/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 467ms/step - accuracy: 0.9616 - loss: 0.0977 - val_accuracy: 0.9873 - val_loss: 0.0393 - learning_rate: 1.0000e-04
# Epoch 28/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9617 - loss: 0.0975 - val_accuracy: 0.9897 - val_loss: 0.0376 - learning_rate: 1.0000e-04
# Epoch 29/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9633 - loss: 0.1011
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 229s 451ms/step - accuracy: 0.9633 - loss: 0.1011 - val_accuracy: 0.9860 - val_loss: 0.0365 - learning_rate: 1.0000e-04
# Epoch 30/30
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 229s 451ms/step - accuracy: 0.9664 - loss: 0.0883 - val_accuracy: 0.9893 - val_loss: 0.0335 - learning_rate: 3.0000e-05
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 25.
# ✅ MobileNetV2 done!
#
# 🔓 Fine-tuning DenseNet121 (unfreeze last 50 layers)...
# Epoch 1/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 306s 532ms/step - accuracy: 0.9755 - loss: 0.0656 - val_accuracy: 0.9971 - val_loss: 0.0089 - learning_rate: 1.0000e-05
# Epoch 2/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 231s 455ms/step - accuracy: 0.9799 - loss: 0.0562 - val_accuracy: 0.9971 - val_loss: 0.0090 - learning_rate: 1.0000e-05
# Epoch 3/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 236s 465ms/step - accuracy: 0.9782 - loss: 0.0618 - val_accuracy: 0.9971 - val_loss: 0.0083 - learning_rate: 1.0000e-05
# Epoch 4/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.9824 - loss: 0.0510 - val_accuracy: 0.9971 - val_loss: 0.0084 - learning_rate: 1.0000e-05
# Epoch 5/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.9825 - loss: 0.0495 - val_accuracy: 0.9971 - val_loss: 0.0076 - learning_rate: 1.0000e-05
# Epoch 6/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 243s 479ms/step - accuracy: 0.9819 - loss: 0.0473 - val_accuracy: 0.9979 - val_loss: 0.0075 - learning_rate: 1.0000e-05
# Epoch 7/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 235s 464ms/step - accuracy: 0.9810 - loss: 0.0510 - val_accuracy: 0.9967 - val_loss: 0.0066 - learning_rate: 1.0000e-05
# Epoch 8/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 238s 470ms/step - accuracy: 0.9849 - loss: 0.0437 - val_accuracy: 0.9984 - val_loss: 0.0067 - learning_rate: 1.0000e-05
# Epoch 9/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 237s 468ms/step - accuracy: 0.9840 - loss: 0.0453 - val_accuracy: 0.9979 - val_loss: 0.0059 - learning_rate: 1.0000e-05
# Epoch 10/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 459ms/step - accuracy: 0.9828 - loss: 0.0468 - val_accuracy: 0.9979 - val_loss: 0.0054 - learning_rate: 1.0000e-05
# Epoch 11/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 234s 461ms/step - accuracy: 0.9830 - loss: 0.0446 - val_accuracy: 0.9975 - val_loss: 0.0066 - learning_rate: 1.0000e-05
# Epoch 12/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 233s 460ms/step - accuracy: 0.9839 - loss: 0.0421 - val_accuracy: 0.9979 - val_loss: 0.0059 - learning_rate: 1.0000e-05
# Epoch 13/15
# 507/507 ━━━━━━━━━━━━━━━━━━━━ 230s 453ms/step - accuracy: 0.9860 - loss: 0.0426 - val_accuracy: 0.9984 - val_loss: 0.0052 - learning_rate: 1.0000e-05
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# ✅ Fine-tuning complete!
# 📊 DenseNet121:
#   Accuracy   : 99.36%
#   Precision  : 99.37%
#   Recall     : 99.36%
#   F1-Score   : 99.36%
#   G-Mean     : 99.22%
#   Error Rate : 0.64%
#
# 📊 VGG16:
#   Accuracy   : 94.38%
#   Precision  : 94.74%
#   Recall     : 94.38%
#   F1-Score   : 94.32%
#   G-Mean     : 93.31%
#   Error Rate : 5.62%
#
# 📊 ResNet50:
#   Accuracy   : 63.15%
#   Precision  : 65.08%
#   Recall     : 63.15%
#   F1-Score   : 62.65%
#   G-Mean     : 59.26%
#   Error Rate : 36.85%
#
# 📊 MobileNetV2:
#   Accuracy   : 98.13%
#   Precision  : 98.20%
#   Recall     : 98.13%
#   F1-Score   : 98.14%
#   G-Mean     : 97.78%
#   Error Rate : 1.87%
#
# 🏆 MODEL COMPARISON:
#       Model  Accuracy  Precision  Recall  F1-Score  G-Mean  Error Rate
# DenseNet121     99.36      99.37   99.36     99.36   99.22        0.64
# MobileNetV2     98.13      98.20   98.13     98.14   97.78        1.87
#       VGG16     94.38      94.74   94.38     94.32   93.31        5.62
#    ResNet50     63.15      65.08   63.15     62.65   59.26       36.85
# 📋 Classification Report — DenseNet121:
#                precision    recall  f1-score   support
#
#   freshapples       1.00      1.00      1.00       395
#   freshbanana       1.00      1.00      1.00       381
#  freshoranges       0.99      1.00      1.00       388
#  rottenapples       1.00      1.00      1.00       601
#  rottenbanana       1.00      1.00      1.00       530
# rottenoranges       1.00      0.99      1.00       403
#  unripe apple       1.00      0.96      0.98       371
# unripe banana       0.99      1.00      0.99       400
# unripe orange       0.95      0.98      0.97       270
#
#      accuracy                           0.99      3739
#     macro avg       0.99      0.99      0.99      3739
#  weighted avg       0.99      0.99      0.99      3739
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_22/2630011077.py in <cell line: 0>()
#     374 sample_img = os.path.join(TEST_DIR, sample_cls,
#     375                           os.listdir(os.path.join(TEST_DIR, sample_cls))[0])
# --> 376 show_gradcam(sample_img, models_dict['DenseNet121'], last_conv, class_names)
#     377
#     378
#
# /tmp/ipykernel_22/2630011077.py in show_gradcam(img_path, model, last_conv, class_names)
#     356     img     = keras.utils.load_img(img_path, target_size=IMG_SIZE)
#     357     arr     = keras.utils.img_to_array(img) / 255.0
# --> 358     heatmap, pred_idx = make_gradcam(np.expand_dims(arr, 0), model, last_conv)
#     359     heatmap_r = cv2.resize(heatmap, IMG_SIZE)
#     360     overlay   = cm.jet(heatmap_r)[:,:,:3] * 0.5 + arr * 0.5
#
# /tmp/ipykernel_22/2630011077.py in make_gradcam(img_array, model, last_conv_name)
#     341     grad_model = keras.Model(
#     342         inputs=model.inputs,
# --> 343         outputs=[model.get_layer(last_conv_name).output, model.output])
#     344     with tf.GradientTape() as tape:
#     345         conv_out, preds = grad_model(img_array)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/model.py in get_layer(self, name, index)
#     208                 if layer.name == name:
#     209                     return layer
# --> 210             raise ValueError(
#     211                 f"No such layer: {name}. Existing layers are: "
#     212                 f"{list(layer.name for layer in self.layers)}."
#
# ValueError: No such layer: conv5_block16_concat. Existing layers are: ['input_layer_1', 'densenet121', 'global_average_pooling2d', 'batch_normalization', 'dense', 'dropout', 'dense_1', 'dropout_1', 'dense_2'].
